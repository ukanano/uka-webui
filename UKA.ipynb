# %% [markdown]
# <a href="https://colab.research.google.com/github/ukanano/uka-webui/blob/main/UKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project UKA
#
# Project page: https://uka.ath.cx
#
# Github : https://github.com/ukanano/uka-webui

# %%
#@title Launch the web UI
import torch
from pathlib import Path

if Path.cwd().name != './uka-webui':
  print("Installing the uka-webui...")

  # !git clone https://github.com/ukanano/uka-webui.git
  # %cd uka-webui

  torver = torch.__version__
  print(f"TORCH: {torver}")
  is_cuda118 = '+cu118' in torver  # 2.1.0+cu118

  textgen_requirements = open('requirements.txt').read().splitlines()
  if is_cuda118:
      textgen_requirements = [req.replace('+cu121', '+cu118').replace('+cu122', '+cu118') for req in textgen_requirements]
  with open('temp_requirements.txt', 'w') as file:
      file.write('\n'.join(textgen_requirements))

  # !pip install -r extensions/openai/requirements.txt --upgrade
  # !pip install -r temp_requirements.txt --upgrade

  print("\033[1;32;1m\n --> If you see a warning about \"previously imported packages\", just ignore it.\033[0;37;0m")
  print("\033[1;32;1m\n --> There is no need to restart the runtime.\n\033[0;37;0m")

  try:
    import flash_attn
  except:
    # !pip uninstall -y flash_attn


# !wget "https://huggingface.co/hotdogs/openuka_v1_1_7B_GGUF/resolve/main/open-uka-v1-1-7B_Q8.gguf" -O models/open-uka-v1-1-7B_Q8.gguf
# !python server.py --share --auto-devices --loader llama.cpp --model models/open-uka-v1-1-7B_Q8.gguf  --n-gpu-layers 128 --character UKA
# Out:
# Installing the uka-webui...
# Cloning into 'uka-webui'...
# remote: Enumerating objects: 16395, done.
# remote: Counting objects: 100% (3381/3381), done.
# remote: Compressing objects: 100% (340/340), done.
# remote: Total 16395 (delta 3201), reused 3085 (delta 3041), pack-reused 13014
# Receiving objects: 100% (16395/16395), 26.42 MiB | 33.40 MiB/s, done.
# Resolving deltas: 100% (11504/11504), done.
# /content/uka-webui
# TORCH: 2.1.0+cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 12.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# ...
